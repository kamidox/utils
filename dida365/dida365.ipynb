# %%
# %matplotlib inline
import dida_event_log as didael

# %%
log = didael.DidaEventLog('dida_20151220.csv', routine_duration=14)
# 设定要统计的时间周期
period = ('2015-12-1', '2016-1-4')

# %%
# 生成时间总览饼图
log.pie_chart(period=period, display_routine=False)
# Out:
# loading data from dida_20151220.csv ...
# loaded 61 items
# save pie chart to dida_20151220.csv_pie_chart.png

# %%
# 生成某个主类别下的子类别的精力分配情况
log.pie_chart_secondary('自我成长', period=period)
# Out:
# save secondary pie chart to dida_20151220.csv_pie_chart_sec.png

# %%
# 生成某个类别的时间投入情况，fields 参数可以是主类别也可以是子类别
log.permanent_action_chart(fields=['编程'], period=period)
# Out:
# save permannet action chart to dida_20151220.csv_pa_chart.png

# %%
log.permanent_action_chart(fields=['阅读', '机器学习', '写作', '编程'], period=period)
# Out:
# save permannet action chart to dida_20151220.csv_pa_chart.png
